# %% [markdown]
# # 问题引出：旅行商问题

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 思路一：贪心算法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 启发式算法引出：

# %% [markdown]
# ![image.png](attachment:image.png)
