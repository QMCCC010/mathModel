# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy.optimize import minimize

# 目标函数：计算每个点到 (a[i], b[i]) 的曼哈顿距离
def fun(x):
    a = np.array([1, 4, 3, 5, 9, 12, 6, 20, 17, 8])
    b = np.array([2, 10, 8, 18, 1, 4, 5, 10, 8, 9])
    f = np.zeros(10)
    for i in range(10):
        f[i] = np.abs(x[0] - a[i]) + np.abs(x[1] - b[i])
    return f

# 总的目标函数：取所有距离中的最大值（最小-最大优化）
def overall_objective(x):
    return np.max(fun(x))

# 初始值
x0 = np.array([6, 6])

# 变量边界（下界和上界）
lb = np.array([3, 4])
ub = np.array([8, 10])

# 定义变量的边界约束
bounds = [(lb[0], ub[0]), (lb[1], ub[1])]

# 使用 SLSQP 方法进行最小化（即最小化最大距离）
result = minimize(overall_objective, x0, method='SLSQP', bounds=bounds)

x = result.x
feval = fun(x)
print("优化后的坐标点x：")
print(x)
print("对应的各个目标函数值feval：")
print(feval)
print("最小的最大距离（即feval中的最大值）：")
print(np.max(feval))
# Out:
# 优化后的坐标点x：
# [7.75000019 8.75000039]
# 对应的各个目标函数值feval：
# [13.50000058  4.9999998   5.50000058 11.9999998   9.0000002   9.0000002
#   5.50000058 13.49999942 10.0000002   0.49999942]
# 最小的最大距离（即feval中的最大值）：
# 13.500000579039686
